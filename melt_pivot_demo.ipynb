# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#pivot"><span class="toc-item-num">1&nbsp;&nbsp;</span>pivot</a></div><div class="lev1"><a href="#melt"><span class="toc-item-num">2&nbsp;&nbsp;</span>melt</a></div><div class="lev1"><a href="#stack"><span class="toc-item-num">3&nbsp;&nbsp;</span>stack</a></div><div class="lev1"><a href="#unstack"><span class="toc-item-num">4&nbsp;&nbsp;</span>unstack</a></div><div class="lev1"><a href="#xs-(-select-multiple-index)"><span class="toc-item-num">5&nbsp;&nbsp;</span>xs ( select multiple index)</a></div><div class="lev1"><a href="#Example"><span class="toc-item-num">6&nbsp;&nbsp;</span>Example</a></div><div class="lev1"><a href="#melt:-a-type-of-unpivoting"><span class="toc-item-num">7&nbsp;&nbsp;</span>melt: a type of unpivoting</a></div>

# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.melt.html#
#
#
# # pivot
# # melt
# # stack
# # unstack
# # xs ( select multiple index)
#
# pivot = rest_index + unstack
#
# pivot_table

# %% [markdown]
# The operations, like stacking and unstacking (as well as pivoting)
# do not lose any information

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd

# %%
from IPython.core.display import HTML
HTML('<style>{}</style>'.format(open('./color_df.css').read()))
# Out:
# <style>
# body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# </style>

# %%
df = pd.DataFrame({'Name' : ['Mike', 'Mikael'],
                   'Height' : [170, 60],
                   'Weight' : [188, 95]}, columns=[['Name', 'Height', 'Weight']])

# %%
df.head()
# Out:
#      Name  Height  Weight
# 0    Mike     170     188
# 1  Mikael      60      95

# %% [markdown]
# melt: a type of unpivoting
#
# wide format -> long format
#
# It “unpivots” a DataFrame from a wide format to a long format

# %%
formatted_df = pd.melt(df, 
        id_vars=['Name'],
        value_vars=['Height', 'Weight'])

formatted_df
# Out:
#      Name variable  value
# 0    Mike   Height    170
# 1  Mikael   Height     60
# 2    Mike   Weight    188
# 3  Mikael   Weight     95

# %%
formatted_df.pivot(index='Name', columns='variable')
formatted_df.pivot(index='Name', columns='variable', values='value')
# Out:
#           value
# variable Height Weight
# Name
# Mikael       60     95
# Mike        170    188
# variable  Height  Weight
# Name
# Mikael        60      95
# Mike         170     188

# %%
formatted_df.pivot(index='Name', columns='variable', values='value').reset_index()
df
# Out:
# variable    Name  Height  Weight
# 0         Mikael      60      95
# 1           Mike     170     188
#      Name  Height  Weight
# 0    Mike     170     188
# 1  Mikael      60      95

# %% [markdown]
# # Example

# %%
import sys
if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO

# %%
df = pd.read_csv(StringIO('''
UID test test_value
uid1 ring1 100
uid1 ring2 103
uid1 ring3 99
uid2 ring1 99
uid2 ring2 101
uid2 ring3 102
'''),
delim_whitespace=True)

df
# Out:
#     UID   test  test_value
# 0  uid1  ring1         100
# 1  uid1  ring2         103
# 2  uid1  ring3          99
# 3  uid2  ring1          99
# 4  uid2  ring2         101
# 5  uid2  ring3         102

# %%
# In this format 
# it is easier to
# add a new variable and measurement
# as the data can simply be added as a new row
# instead of requiring a change of structure to DataFrame by adding a new column.

df
# Out:
#     UID   test  test_value
# 0  uid1  ring1         100
# 1  uid1  ring2         103
# 2  uid1  ring3          99
# 3  uid2  ring1          99
# 4  uid2  ring2         101
# 5  uid2  ring3         102

# %%
df.pivot(index='UID', columns='test')
df_galaxy = df.pivot(index='UID', columns='test', values='test_value')
df_galaxy
# Out:
#      test_value
# test      ring1 ring2 ring3
# UID
# uid1        100   103    99
# uid2         99   101   102
# test  ring1  ring2  ring3
# UID
# uid1    100    103     99
# uid2     99    101    102

# %%
df_galaxy.reset_index(inplace=True)

# %%
pd.melt(df_galaxy, 
        id_vars=['UID'],
        value_vars=['ring1', 'ring2', 'ring3'])
# Out:
#     UID   test  value
# 0  uid1  ring1    100
# 1  uid2  ring1     99
# 2  uid1  ring2    103
# 3  uid2  ring2    101
# 4  uid1  ring3     99
# 5  uid2  ring3    102

# %%
_.sort_values(by=['UID', 'test'])
# Out:
#     UID   test  value
# 0  uid1  ring1    100
# 2  uid1  ring2    103
# 4  uid1  ring3     99
# 1  uid2  ring1     99
# 3  uid2  ring2    101
# 5  uid2  ring3    102

# %%
df.pivot(index='UID', columns='test')
# Out:
#      test_value
# test      ring1 ring2 ring3
# UID
# uid1        100   103    99
# uid2         99   101   102

# %%
_.stack()
# Out:
#             test_value
# UID  test
# uid1 ring1         100
#      ring2         103
#      ring3          99
# uid2 ring1          99
#      ring2         101
#      ring3         102

# %%
_.reset_index()
# Out:
#     UID   test  test_value
# 0  uid1  ring1         100
# 1  uid1  ring2         103
# 2  uid1  ring3          99
# 3  uid2  ring1          99
# 4  uid2  ring2         101
# 5  uid2  ring3         102

# %%
df.pivot(index='UID', columns='test', values='test_value')
# Out:
# test  ring1  ring2  ring3
# UID
# uid1    100    103     99
# uid2     99    101    102

# %%
_.stack()
# Out:
# UID   test
# uid1  ring1    100
#       ring2    103
#       ring3     99
# uid2  ring1     99
#       ring2    101
#       ring3    102
# dtype: int64

# %%
_.unstack()
# Out:
# test  ring1  ring2  ring3
# UID
# uid1    100    103     99
# uid2     99    101    102

# %%
df.pivot(index='UID', columns='test', values='test_value')
# Out:
# test  ring1  ring2  ring3
# UID
# uid1    100    103     99
# uid2     99    101    102

# %%
_.stack()
# Out:
# UID   test
# uid1  ring1    100
#       ring2    103
#       ring3     99
# uid2  ring1     99
#       ring2    101
#       ring3    102
# dtype: int64

# %%
pd.DataFrame(_)
# Out:
#               0
# UID  test
# uid1 ring1  100
#      ring2  103
#      ring3   99
# uid2 ring1   99
#      ring2  101
#      ring3  102

# %%
df
# Out:
#     UID   test  test_value
# 0  uid1  ring1         100
# 1  uid1  ring2         103
# 2  uid1  ring3          99
# 3  uid2  ring1          99
# 4  uid2  ring2         101
# 5  uid2  ring3         102

# %%
df.set_index(['UID', 'test']).unstack()
# Out:
#      test_value
# test      ring1 ring2 ring3
# UID
# uid1        100   103    99
# uid2         99   101   102

# %%
df.pivot(index='UID', columns='test') # pivot = rest_index + unstack
# Out:
#      test_value
# test      ring1 ring2 ring3
# UID
# uid1        100   103    99
# uid2         99   101   102

# %% [markdown]
# # melt: a type of unpivoting
#
# melt: a type of unpivoting
#
# wide format -> long format

# %%
df = pd.read_csv(StringIO('''
UID test test_value
uid1 ring1 100
uid1 ring2 103
uid1 ring3 99
uid2 ring1 99
uid2 ring2 101
uid2 ring3 102
'''),
delim_whitespace=True)

df
# Out:
#     UID   test  test_value
# 0  uid1  ring1         100
# 1  uid1  ring2         103
# 2  uid1  ring3          99
# 3  uid2  ring1          99
# 4  uid2  ring2         101
# 5  uid2  ring3         102

# %%
df.pivot(index='UID', columns='test')
# Out:
#      test_value
# test      ring1 ring2 ring3
# UID
# uid1        100   103    99
# uid2         99   101   102

# %%
df_foo = df.pivot(index='UID', columns='test')
df_foo
# Out:
#      test_value
# test      ring1 ring2 ring3
# UID
# uid1        100   103    99
# uid2         99   101   102

# %%
df_foo.xs(key='test_value', level=0,axis=1) # axis=1 <=> columns
df_foo.xs(key='test_value', axis=1) # axis=1 <=> columns
# Out:
# test  ring1  ring2  ring3
# UID
# uid1    100    103     99
# uid2     99    101    102
# test  ring1  ring2  ring3
# UID
# uid1    100    103     99
# uid2     99    101    102

# %%
df_foo.xs(key='test_value', level=0, axis=1).reset_index()
# Out:
# test   UID  ring1  ring2  ring3
# 0     uid1    100    103     99
# 1     uid2     99    101    102

# %%
# melt: a type of unpivoting
# wide format -> long format
pd.melt(_,
        id_vars=['UID'],
        value_vars=['ring1', 'ring2', 'ring3'])
# Out:
#     UID   test  value
# 0  uid1  ring1    100
# 1  uid2  ring1     99
# 2  uid1  ring2    103
# 3  uid2  ring2    101
# 4  uid1  ring3     99
# 5  uid2  ring3    102

# %%
pd.melt(__,
        ['UID'],
        var_name="test_field",
        value_name="test_value")
# Out:
#     UID test_field  test_value
# 0  uid1      ring1         100
# 1  uid2      ring1          99
# 2  uid1      ring2         103
# 3  uid2      ring2         101
# 4  uid1      ring3          99
# 5  uid2      ring3         102
